# %% [markdown]
# <h3>Pandas DataFrame Experimentation: Basic Inspection

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/joycemara/european-fashion-store-multitable-dataset

# %%
import pandas as pd
import numpy as np

# %%
# Load raw data csv:
campaigns_df = pd.read_csv('archive/dataset_fashion_store_campaigns.csv')
channels_df = pd.read_csv('archive/dataset_fashion_store_channels.csv')
customers_df = pd.read_csv('archive/dataset_fashion_store_customers.csv')
products_df = pd.read_csv('archive/dataset_fashion_store_products.csv')
sales_df = pd.read_csv('archive/dataset_fashion_store_sales.csv')
sale_items_df = pd.read_csv('archive/dataset_fashion_store_salesitems.csv')
stock_df = pd.read_csv('archive/dataset_fashion_store_stock.csv')

# %%
campaigns_df.head(10)
# Out:
#    campaign_id          campaign_name  start_date    end_date         channel  \
# 0            1      Spring Flash Sale  2025-04-01  2025-04-07           Email
# 1            2       Easter Promotion  2025-04-08  2025-04-15    Social Media
# 2            3  Mother's Day Campaign  2025-05-01  2025-05-09           Email
# 3            4   Mid-Season Clearance  2025-05-10  2025-05-19      App Mobile
# 4            5              TIVA Week  2025-05-20  2025-05-31    Social Media
# 5            6        June Price Drop  2025-06-01  2025-06-09  Website Banner
# 6            7     Early Summer Deals  2025-06-10  2025-06-17           Email
#
#   discount_type discount_value
# 0    Percentage         10.00%
# 1         Fixed             10
# 2    Percentage         25.00%
# 3    Percentage         30.00%
# 4    Percentage         30.00%
# 5    Percentage         10.00%
# 6         Fixed             12

# %% [markdown]
# <h4>Summarize Data

# %%
campaigns_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   campaign_id     7 non-null      int64
#  1   campaign_name   7 non-null      str
#  2   start_date      7 non-null      str
#  3   end_date        7 non-null      str
#  4   channel         7 non-null      str
#  5   discount_type   7 non-null      str
#  6   discount_value  7 non-null      str
# dtypes: int64(1), str(6)
# memory usage: 524.0 bytes

# %%
campaigns_df.describe()
# Out:
#        campaign_id
# count     7.000000
# mean      4.000000
# std       2.160247
# min       1.000000
# 25%       2.500000
# 50%       4.000000
# 75%       5.500000
# max       7.000000

# %%
campaigns_df.shape
# Out:
# (7, 7)

# %%
# Value counts for a given column
campaigns_df['discount_type'].value_counts()
# Out:
# discount_type
# Percentage    5
# Fixed         2
# Name: count, dtype: int64

# %%
# Number of unique values of a given column
campaigns_df['campaign_name'].nunique()
# Out:
# 7

# %%
# Datatype of the values in each column
campaigns_df.dtypes
# Out:
# campaign_id       int64
# campaign_name       str
# start_date          str
# end_date            str
# channel             str
# discount_type       str
# discount_value      str
# dtype: object
